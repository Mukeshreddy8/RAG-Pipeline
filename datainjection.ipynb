# %%
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader("speech.txt")
text_document=loader.load()
text_document
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="1961 Inaugural address. John F. Kennedy giving a speech. Much of President John F. Kennedy's pithy 1,366-word inaugural address, delivered on Jan. 20, 1961 ...1961 Inaugural address. John F. Kennedy giving a speech. Much of President John F. Kennedy's pithy 1,366-word inaugural address, delivered on Jan. 20, 1961 ...")]

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_document=PyPDFLoader("Day.pdf")
docs=pdf_document.load()
docs
# Out:
# [Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com); modified using iText 4.2.0 by 1T3XT', 'creator': 'pdftk-java 3.2.2', 'creationdate': '2022-10-25T12:28:03+02:00', 'moddate': '2025-03-01T21:19:24-08:00', 'source': 'Day.pdf', 'total_pages': 14, 'page': 0, 'page_label': '1'}, page_content='A Run a Day Won’t Keep the Hacker Away: Inference Attacks on\nEndpoint Privacy Zones in Fitness Tracking Social Networks\nKarel Dhondt\nimec-DistriNet, KU Leuven\nGhent, Belgium\nkarel.dhondt@kuleuven.be\nVictor Le Pochat\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nvictor.lepochat@kuleuven.be\nAlexios Voulimeneas\nimec-DistriNet, KU Leuven\nGhent, Belgium\nalex.voulimeneas@kuleuven.be\nWouter Joosen\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nwouter.joosen@kuleuven.be\nStijn Volckaert\nimec-DistriNet, KU Leuven\nGhent, Belgium\nstijn.volckaert@kuleuven.be\nABSTRACT\nFitness tracking social networks such as Strava allow users to record\nsports activities and share them 
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader=WebBaseLoader(web_path="https://en.wikipedia.org/wiki/History_of_India",)
web_load=loader.load()
web_load
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
doc_splitter=text_splitter.split_documents(docs)

doc_splitter
# Out:
# [Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com); modified using iText 4.2.0 by 1T3XT', 'creator': 'pdftk-java 3.2.2', 'creationdate': '2022-10-25T12:28:03+02:00', 'moddate': '2025-03-01T21:19:24-08:00', 'source': 'Day.pdf', 'total_pages': 14, 'page': 0, 'page_label': '1'}, page_content='A Run a Day Won’t Keep the Hacker Away: Inference Attacks on\nEndpoint Privacy Zones in Fitness Tracking Social Networks\nKarel Dhondt\nimec-DistriNet, KU Leuven\nGhent, Belgium\nkarel.dhondt@kuleuven.be\nVictor Le Pochat\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nvictor.lepochat@kuleuven.be\nAlexios Voulimeneas\nimec-DistriNet, KU Leuven\nGhent, Belgium\nalex.voulimeneas@kuleuven.be\nWouter Joosen\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nwouter.joosen@kuleuven.be\nStijn Volckaert\nimec-DistriNet, KU Leuven'),
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
result=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_document=result.split_documents(docs)
final_document
# Out:
# [Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com); modified using iText 4.2.0 by 1T3XT', 'creator': 'pdftk-java 3.2.2', 'creationdate': '2022-10-25T12:28:03+02:00', 'moddate': '2025-03-01T21:19:24-08:00', 'source': 'Day.pdf', 'total_pages': 14, 'page': 0, 'page_label': '1'}, page_content='A Run a Day Won’t Keep the Hacker Away: Inference Attacks on\nEndpoint Privacy Zones in Fitness Tracking Social Networks\nKarel Dhondt\nimec-DistriNet, KU Leuven\nGhent, Belgium\nkarel.dhondt@kuleuven.be\nVictor Le Pochat\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nvictor.lepochat@kuleuven.be\nAlexios Voulimeneas\nimec-DistriNet, KU Leuven\nGhent, Belgium\nalex.voulimeneas@kuleuven.be\nWouter Joosen\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nwouter.joosen@kuleuven.be\nStijn Volckaert\nimec-DistriNet, KU Leuven'),
# ...

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
embedding_text=OpenAIEmbeddings(model="text-embedding-3-large")

# %%
text="Hi this is mukesh, and i like AI "

result_text=embedding_text.embed_query(text)
result_text
# Out:
# [-0.029867853969335556,
#  -0.014264819212257862,
#  -0.016912778839468956,
#  -0.011631094850599766,
#  0.023233717307448387,
#  -0.001404949463903904,
#  0.014905454590916634,
#  0.01192293968051672,
#  0.01099757757037878,
#  0.02803136594593525,
#  -0.00689039146527648,
#  -0.037042971700429916,
#  0.021226393058896065,
#  -0.01142466813325882,
#  -0.011844639666378498,
#  0.029070619493722916,
#  0.0014663436450064182,
#  -0.007943881675601006,
#  -0.0290279109030962,
#  -0.005395575426518917,
#  0.027262603864073753,
#  -0.016172489151358604,
#  -0.05429742485284805,
#  0.007431372534483671,
#  0.004043122287839651,
#  -0.002699567237868905,
#  0.007837108336389065,
#  0.01919059455394745,
#  -0.04504380002617836,
#  -0.02072812058031559,
#  0.02225140854716301,
#  0.015346781350672245,
#  0.012826948426663876,
#  0.006609223783016205,
#  0.03727075457572937,
#  -0.023091353476047516,
#  -0.006306701339781284,
#  -0.004662403371185064,
#  -0.0037334817461669445,
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_document=PyPDFLoader("Day.pdf")
docs=pdf_document.load()
docs
# Out:
# [Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com); modified using iText 4.2.0 by 1T3XT', 'creator': 'pdftk-java 3.2.2', 'creationdate': '2022-10-25T12:28:03+02:00', 'moddate': '2025-03-01T21:19:24-08:00', 'source': 'Day.pdf', 'total_pages': 14, 'page': 0, 'page_label': '1'}, page_content='A Run a Day Won’t Keep the Hacker Away: Inference Attacks on\nEndpoint Privacy Zones in Fitness Tracking Social Networks\nKarel Dhondt\nimec-DistriNet, KU Leuven\nGhent, Belgium\nkarel.dhondt@kuleuven.be\nVictor Le Pochat\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nvictor.lepochat@kuleuven.be\nAlexios Voulimeneas\nimec-DistriNet, KU Leuven\nGhent, Belgium\nalex.voulimeneas@kuleuven.be\nWouter Joosen\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nwouter.joosen@kuleuven.be\nStijn Volckaert\nimec-DistriNet, KU Leuven\nGhent, Belgium\nstijn.volckaert@kuleuven.be\nABSTRACT\nFitness tracking social networks such as Strava allow users to record\nsports activities and share them 
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
doc_splitter=text_splitter.split_documents(docs)
doc_splitter
# Out:
# [Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com); modified using iText 4.2.0 by 1T3XT', 'creator': 'pdftk-java 3.2.2', 'creationdate': '2022-10-25T12:28:03+02:00', 'moddate': '2025-03-01T21:19:24-08:00', 'source': 'Day.pdf', 'total_pages': 14, 'page': 0, 'page_label': '1'}, page_content='A Run a Day Won’t Keep the Hacker Away: Inference Attacks on\nEndpoint Privacy Zones in Fitness Tracking Social Networks\nKarel Dhondt\nimec-DistriNet, KU Leuven\nGhent, Belgium\nkarel.dhondt@kuleuven.be\nVictor Le Pochat\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nvictor.lepochat@kuleuven.be\nAlexios Voulimeneas\nimec-DistriNet, KU Leuven\nGhent, Belgium\nalex.voulimeneas@kuleuven.be\nWouter Joosen\nimec-DistriNet, KU Leuven\nLeuven, Belgium\nwouter.joosen@kuleuven.be\nStijn Volckaert\nimec-DistriNet, KU Leuven'),
# ...

# %%
from langchain_openai import OpenAIEmbeddings
embedding_text=OpenAIEmbeddings(model="text-embedding-3-large")

# %%
from langchain_community.vectorstores import Chroma
db=Chroma.from_documents(doc_splitter,embedding_text)
db

# %%
query="those parts of the track that might reveal the sensitive location, i.e. are near this location"
query_result=db.similarity_search(query)
print(query_result)
# Out:
# [Document(metadata={'creator': 'pdftk-java 3.2.2', 'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com); modified using iText 4.2.0 by 1T3XT', 'source': 'Day.pdf', 'total_pages': 14, 'creationdate': '2022-10-25T12:28:03+02:00', 'page_label': '3', 'moddate': '2025-03-01T21:19:24-08:00', 'page': 2}, page_content='to all the activities of the owner. The goal of the EPZ is then to hide\nthose parts of the track that might reveal the sensitive location, i.e.,\nare near this location. Only the owner of the activity 𝑎can view\nthe full track, including its actual start and finish points (together\nthe ‘endpoints’), as well as the layout of the EPZ itself (shown\nin Figure 2a). Other users only see a cloaked activity 𝑎′as defined\nin Definition 1 and depicted in Figure 2b. Concretely, in such a'), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com); modified using iText 4.2.0 by 1T3XT', 'creationdate': '2022-10-25T12:28:03+02:00', 'page': 0, 'source': 'Day.pdf
# ...
